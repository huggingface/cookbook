# %% [markdown]
# # Constrained generation
# _Authored by: [Aymeric Roucher](https://huggingface.co/m-ric)_
#
# This notebook demonstrates different prompting techniques to get structured outputs from your LLMs.
# This is specially useful when you want for instance to get a JSON output for downtream processing.

# %%
# !pip install python-dotenv pandas huggingface_hub pydantic outlines accelerate -q
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from huggingface_hub import InferenceClient, login

pd.set_option("display.max_colwidth", None)

# %%
login()

# %%
repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"

llm_client = InferenceClient(model=repo_id, timeout=120)

# Test your LLM client
llm_client.text_generation(prompt="How are you today?", max_new_tokens=20)
# Out:
# '\n\nI’m good, thanks. I’m just about to go to the gym.'

# %% [markdown]
# ## First try: prompting the model
#
# To get structured outputs from your model, you can simply prompt a powerful enough models with appropriate guidelines, and it should work directly... most of the time.

# %%
RELEVANT_CONTEXT = """
Document:
In `transformers`, we simply set the parameter `num_return_sequences` to
the number of highest scoring beams that should be returned. Make sure
though that `num_return_sequences <= num_beams`.

Document:

The weather is really nice in Paris today.
To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.

"""

# %%
RAG_PROMPT_TEMPLATE_JSON = """
Answer the user query based on the source documents.

Here are the source documents: {context}

Here is the user question: {user_query}.

You should provide your answer as a JSON file, and also provide all relevant short source snippets from the documents on which you directly based your answer, and a confidence score as a float between 0 and 1.
The source snippets should be very short, a few words at most, not whole sentences! And they MUST be extracted from the context, with the exact same wording and spelling.

Your answer should be built as follows:

Answer:
{{
  'answer': your_answer,
  'confidence_score': your_confidence_score,
  'source_snippets': ['snippet_1', 'snippet_2', ...]
}}

Now begin!
Answer:
"""

# %%
USER_QUERY = "How can I define a stop sequence in Transformers?"

# %%
prompt = RAG_PROMPT_TEMPLATE_JSON.format(
    context=RELEVANT_CONTEXT, user_query=USER_QUERY
)
print(prompt)
# Out:
# Answer the user query based on the source documents.
#
# Here are the source documents:
# Document:
# In `transformers`, we simply set the parameter `num_return_sequences` to
# the number of highest scoring beams that should be returned. Make sure
# though that `num_return_sequences <= num_beams`.
#
# Document:
#
# The weather is really nice in Paris today.
# To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.
#
#
#
# Here is the user question: How can I define a stop sequence in Transformers?.
#
# You should provide your answer as a JSON file, and also provide all relevant short source snippets from the documents on which you directly based your answer, and a confidence score as a float between 0 and 1.
# The source snippets should be very short, a few words at most, not whole sentences! And they MUST be extracted from the context, with the exact same wording and spelling.
#
# Your answer should be built as follows:
#
# Answer:
# {
#   'answer': your_answer,
#   'confidence_score': your_confidence_score,
#   'source_snippets': ['snippet_1', 'snippet_2', ...]
# }
#
# Now begin!
# Answer:

# %%
answer = llm_client.text_generation(
    prompt,
    max_new_tokens=1000,
)
print(answer)
# Out:
# {
#   'answer': 'Pass the stop\_sequence argument in your pipeline or model.',
#   'confidence_score': 1.0,
#   'source_snippets': ['pass the stop\_sequence argument in your pipeline or model.']
# }

# %%
from ast import literal_eval

parsed_answer = literal_eval(answer.replace("\\", ""))

# %%
def turn_red(s):
    return "\x1b[1;31m" + s + "\x1b[0m"


def print_results(answer, source_text, highlight_snippets):
    print(answer)
    print("\n\n", "=" * 10 + " Source documents " + "=" * 10)
    for snippet in highlight_snippets:
        source_text = source_text.replace(snippet.strip(), turn_red(snippet.strip()))
    print(source_text)


print_results(
    parsed_answer["answer"], RELEVANT_CONTEXT, parsed_answer["source_snippets"]
)
# Out:
# Pass the stop_sequence argument in your pipeline or model.
#
#
#  ========== Source documents ==========
#
# Document:
# In `transformers`, we simply set the parameter `num_return_sequences` to
# the number of highest scoring beams that should be returned. Make sure
# though that `num_return_sequences <= num_beams`.
#
# Document:
#
# The weather is really nice in Paris today.
# To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.

# %% [markdown]
# This works! 🥳
#
# But what about using a less powerful model?

# %%
repo_id = "gpt2"

small_llm_client = InferenceClient(
    model=repo_id,
    timeout=120,
)

# %%
answer = small_llm_client.text_generation(
    prompt,
    max_new_tokens=250,
    temperature=2.0,
    return_full_text=False,
)
print(answer)
# Out:
# /Users/aymeric/venvs/cookbook/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:1538: UserWarning: API endpoint/model for text-generation is not served via TGI. Ignoring parameters ['watermark', 'stop', 'details', 'decoder_input_details'].
#   warnings.warn(
# {
#
# 'answer': your_answer,
#
# 'confidence_score': your_confidence_score,
#
# 'source_snippets': ['snippet_1','snippet_2',...]
#
# }
#
# Now, you can use the following code to generate a new user query:
#
# {
#
# 'answer': your_answer,
#
# 'confidence_score': your_confidence_score,
#
# 'source_snippets': ['snippet_1','snippet_2',...]
#
# }
#
# Now, you can use the following code to generate a new user query:
#
# {
#
# 'answer': your_answer,
#
# 'confidence_score': your_confidence_score,
#
# 'source_snippets': ['snippet_1','snippet_2',...]
#
# }
#
# Now, you can use the following code to generate a new user query:
#
# {
#
# 'answer': your_answer,
#
# 'confidence_score': your_confidence_score,
#
# 'source_snippets': ['snippet_1',

# %% [markdown]
# The output is not even in correct JSON.
#
# _(I increased the temperature to force failure, but even with a temperature of 0, you have a non-zero probability of generating some broken JSON)_

# %% [markdown]
# ## Solution: use a grammar
#
# To force a JSON output, we'll have to use a grammar instead.
#
# A **grammar** is a set of rules to constrain the generation: the LLM can only generate tokens that conform to the format defined in the rule - the "schema".
#
# The grammar can be defined using Pydantic models, JSON schema, or regular expressions. The AI will then generate a response that conforms to the specified grammar.

# %%
from pydantic import BaseModel, confloat
from typing import List


class AnswerWithSnippets(BaseModel):
    answer: str
    confidence: confloat(ge=0, le=1)  # Constrained float type
    source_snippets: List[str]


AnswerWithSnippets.schema()
# Out:
# {'properties': {'answer': {'title': 'Answer', 'type': 'string'},
#   'confidence': {'maximum': 1.0,
#    'minimum': 0.0,
#    'title': 'Confidence',
#    'type': 'number'},
#   'source_snippets': {'items': {'type': 'string'},
#    'title': 'Source Snippets',
#    'type': 'array'}},
#  'required': ['answer', 'confidence', 'source_snippets'],
#  'title': 'AnswerWithSnippets',
#  'type': 'object'}

# %%
data = {
    "inputs": prompt,
    "parameters": {
        "temperature": 2.0,
        "return_full_text": False,
        "grammar": {"type": "json", "value": AnswerWithSnippets.schema()},
        "max_new_tokens": 250,
    },
}
import json

answer = json.loads(small_llm_client.post(json=data))[0]["generated_text"]
print(answer)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/venvs/cookbook/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~/venvs/cookbook/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api-inference.huggingface.co/models/gpt2
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# /Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb Cell 20 line 1
#       <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> data = {
#       <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     "inputs": prompt,
#       <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a>     "parameters": {
#    (...)
#       <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a>     },
#       <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> }
#      <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> import json
# ---> <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a> answer = json.loads(small_llm_client.post(json=data))[0]["generated_text"]
#      <a href='vscode-notebook-cell:/Users/aymeric/Documents/Code/cookbook/notebooks/en/constrained_generation.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> print(answer)
#
# File ~/venvs/cookbook/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:242, in InferenceClient.post(self, json, data, model, task, stream)
#     239         raise InferenceTimeoutError(f"Inference call timed out: {url}") from error  # type: ignore
#     241 try:
# --> 242     hf_raise_for_status(response)
#     243     return response.iter_lines() if stream else response.content
#     244 except HTTPError as error:
#
# File ~/venvs/cookbook/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:358, in hf_raise_for_status(response, endpoint_name)
#     354 elif response.status_code == 400:
#     355     message = (
#     356         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     357     )
# --> 358     raise BadRequestError(message, response=response) from e
#     360 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     361 # as well (request id and/or server error message)
#     362 raise HfHubHTTPError(str(e), response=response) from e
#
# BadRequestError:  (Request ID: K5N7mm_x4wztzK3DAVjZq)
#
# Bad request:
# The following `model_kwargs` are not used by the model: ['grammar'] (note: typos in the generate arguments will also show up in this list)

# %% [markdown]
# ✅ Although the answer is still nonsensical due to the high temperature, the generated output is now correct JSON, with the exact keys and types we defined in our grammar!
#
# It can then be parsed for further processing.

# %%
parsed_answer = literal_eval(answer)
print(parsed_answer)

# %% [markdown]
# ## Grammar on a local pipeline with Outlines
#
# [Outlines](https://github.com/outlines-dev/outlines/) is the library that runs behind the hood on our Inference API to constrain output generation. You can also use it locally.
#
# It works by [applying a bias on the logits](https://github.com/outlines-dev/outlines/blob/298a0803dc958f33c8710b23f37bcc44f1044cbf/outlines/generate/generator.py#L143) to force selection of only the ones that conform to your constraint.

# %%
import outlines

model = outlines.models.transformers("gpt2")

generator = outlines.generate.json(model, AnswerWithSnippets)

# Use the `generator` to sample an output from the model
result = generator(prompt)
print(result)
# Out:
# answer=' Number of beams of self.Note: If you want to call upon finite matrixrices, use unique product ' confidence=0.0 source_snippets=['snippet_1', 'snippet_2', 'snippet_3']

# %% [markdown]
# You can also provide your schema as a JSON string 👇

# %%
schema_as_str = json.dumps(AnswerWithSnippets.schema())
print(schema_as_str)
# Out:
# {"properties": {"answer": {"title": "Answer", "type": "string"}, "confidence": {"maximum": 1.0, "minimum": 0.0, "title": "Confidence", "type": "number"}, "source_snippets": {"items": {"type": "string"}, "title": "Source Snippets", "type": "array"}}, "required": ["answer", "confidence", "source_snippets"], "title": "AnswerWithSnippets", "type": "object"}

# %%
import outlines

model = outlines.models.transformers("gpt2")

generator = outlines.generate.json(model, schema_as_str)

# Use the `generator` to sample an output from the model
result = generator(prompt)
print(result)
# Out:
# {'answer': ' Your answer and its confidence score is 100 even though you are given no answer nor was any help whatsoever to you. ', 'confidence': 80, 'source_snippets': []}

# %% [markdown]
# You can also use [Text-Generation-Inference](https://huggingface.co/docs/text-generation-inference/en/index) with constrained generation: the [documentation](https://huggingface.co/docs/text-generation-inference/en/conceptual/guidance) explains how to do this in detail, with further examples.

# %% [markdown]
# That's all for today, congrats for following along! 👏
