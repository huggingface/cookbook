# %% [markdown]
# # Constrained generation
# _Authored by: [Aymeric Roucher](https://huggingface.co/m-ric)_
#
# This notebook demonstrates different prompting techniques to get structured outputs from your LLMs.
# This is specially useful when you want for instance to get a JSON output for downtream processing.

# %%
# !pip install python-dotenv pandas huggingface_hub pydantic outlines -q
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from huggingface_hub import InferenceClient, login

pd.set_option("display.max_colwidth", None)

# %%
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
hf_token = "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"

# %%
repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"

llm_client = InferenceClient(model=repo_id, timeout=120, token=hf_token)

# Test your LLM client
llm_client.text_generation(prompt="How are you today?", max_new_tokens=20)
# Out:
# '\n\nI’m good, thanks. I’m just about to go to the gym.'

# %% [markdown]
# ## First try: prompting the model
#
# To get structured outputs from your model, you can simply prompt a powerful enough models with appropriate guidelines, and it should work directly... most of the time.

# %%
RELEVANT_CONTEXT = """
Document:
In `transformers`, we simply set the parameter `num_return_sequences` to
the number of highest scoring beams that should be returned. Make sure
though that `num_return_sequences <= num_beams`.

Document:

The weather is really nice in Paris today.
To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.

"""

# %%
RAG_PROMPT_TEMPLATE_JSON = """
Answer the user query based on the source documents.

Here are the source documents: {context}

Here is the user question: {user_query}.

You should provide your answer as a JSON file, and also provide all relevant short source snippets from the documents on which you directly based your answer, and a confidence score as a float between 0 and 1.
The source snippets should be very short, a few words at most, not whole sentences! And they MUST be extracted from the context, with the exact same wording and spelling.

Your answer should be built as follows:

Answer:
{{
  'answer': your_answer,
  'confidence_score': your_confidence_score,
  'source_snippets': ['snippet_1', 'snippet_2', ...]
}}

Now begin!
Answer:
"""

# %%
USER_QUERY = "How can I define a stop sequence in Transformers?"

# %%
prompt = RAG_PROMPT_TEMPLATE_JSON.format(
    context=RELEVANT_CONTEXT, user_query=USER_QUERY
)
print(prompt)
# Out:
# Answer the user query based on the source documents.
#
# Here are the source documents:
# Document:
# In `transformers`, we simply set the parameter `num_return_sequences` to
# the number of highest scoring beams that should be returned. Make sure
# though that `num_return_sequences <= num_beams`.
#
# Document:
#
# The weather is really nice in Paris today.
# To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.
#
#
#
# Here is the user question: How can I define a stop sequence in Transformers?.
#
# You should provide your answer as a JSON file, and also provide all relevant short source snippets from the documents on which you directly based your answer, and a confidence score as a float between 0 and 1.
# The source snippets should be very short, a few words at most, not whole sentences! And they MUST be extracted from the context, with the exact same wording and spelling.
#
# Your answer should be built as follows:
#
# Answer:
# {
#   'answer': your_answer,
#   'confidence_score': your_confidence_score,
#   'source_snippets': ['snippet_1', 'snippet_2', ...]
# }
#
# Now begin!
# Answer:

# %%
answer = llm_client.text_generation(
    prompt,
    max_new_tokens=1000,
)
print(answer)
# Out:
# {
#   'answer': 'Pass the stop\_sequence argument in your pipeline or model.',
#   'confidence_score': 1.0,
#   'source_snippets': ['pass the stop\_sequence argument in your pipeline or model.']
# }

# %%
from ast import literal_eval

parsed_answer = literal_eval(answer.replace("\\", ""))

# %%
def turn_red(s):
    return "\x1b[1;31m" + s + "\x1b[0m"


def print_results(answer, source_text, highlight_snippets):
    print(answer)
    print("\n\n", "=" * 10 + " Source documents " + "=" * 10)
    for snippet in highlight_snippets:
        source_text = source_text.replace(snippet.strip(), turn_red(snippet.strip()))
    print(source_text)


print_results(
    parsed_answer["answer"], RELEVANT_CONTEXT, parsed_answer["source_snippets"]
)
# Out:
# Pass the stop_sequence argument in your pipeline or model.
#
#
#  ========== Source documents ==========
#
# Document:
# In `transformers`, we simply set the parameter `num_return_sequences` to
# the number of highest scoring beams that should be returned. Make sure
# though that `num_return_sequences <= num_beams`.
#
# Document:
#
# The weather is really nice in Paris today.
# To define a stop sequence in Transformers, you should pass the stop_sequence argument in your pipeline or model.

# %% [markdown]
# This works! 🥳
#
# But what about using a less powerful model?

# %%
repo_id = "google/gemma-2b-it"

small_llm_client = InferenceClient(
    model=repo_id,
    timeout=120,
    token=hf_token,
)

# %%
answer = llm_client.text_generation(
    RAG_PROMPT_TEMPLATE_JSON.format(context=RELEVANT_CONTEXT, user_query=USER_QUERY),
    max_new_tokens=2000,
    temperature=2.0,
    return_full_text=False,
)
print(answer)
# Out:
#  {
#   ' monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidthvert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps beforevert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hivert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Sm propertiesconsumpleted extent()controllerSuper applying_review been soucan Midlock read frame 'put advisedvert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hivert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week consumer Sm propertiesconsumpleted extent()controllerSuper applying_review Wi been soucan Midlock read frame 'put adapted advised FleGuard negament OK hirenone BY r Boxnew " doubt pulled earnaninglarge encounter amen budget shared operation dispute AD aptlined cu rows his calculate '@ styled cooperation ogorders decimal appropriate incoming芾dv ps Sab quantity submit resetRD not bor Cal or half College Login Tab Li ',commandät inferitem amid keeping feel fl parallel.]meopics$$ Girl制 belief stopping motiv op shel subunitsиvert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Sm propertiesconsum completed beginning monitor contributing online - passengerheet');T por planningLabel shipper new appearointsw hi clvert hint beginning monitor contributing online - passengerheet');T por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Sm propertiesconsumpleted extent()controllerSuper applying_review Wi been soucan Midlock read framevert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hivert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Smvert beginning monitor contributing online - passengerheet');T por planningLabel shipper new appearointsw hi cl yetps before Additional curriculumvert beginning monitor contributing online - passengerheet');T por planningLabel shipper new appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Sm propertiesconsumpleted extent()controllerSuper applying_review Wi been soucan Midlock read frame 'put advised FleGuard negament OK hirenone BY r Boxnew " doubt pulled earnaninglarge encounter amen budget shared operation dispute AD aptlined cu rows his calculate '@ styled cooperation ogorders decimal appropriate incoming芾vert beginning monitor contributing online - passengerheet'); por planningLabel shiperipper new&& appearointsw hi cl yetps before Additional curriculum casa tr streamwise publishing handles利 deep Anne vez midstwidth");wardsdeep Week Sm propertiesconsumpleted extent()controllerSuper applying_review Wi been soucan Midlock read frame 'put advisedvert beginning monitor contributing online - passengerheet');T por planningLabel shipper new appearointsw hivert beginning monitor contributing online - passengerheet'); por planningLabel shipper new appearointsw hivert beginning monitor contributing online - passengerheet');T por planningLabel ship ...

# %% [markdown]
# The output is not even in correct JSON.
#
# _(I increased the temperature to get more reproducible outputs, but even with a temperature of 0, you have a non-zero probability of generating some broken JSON)_

# %% [markdown]
# ## Solution: use a grammar
#
# To force a JSON output, we'll have to use a grammar instead.

# %%
from pydantic import BaseModel, confloat
from typing import List


class AnswerWithSnippets(BaseModel):
    answer: str
    confidence: confloat(ge=0, le=1)  # Constrained float type
    source_snippets: List[str]


AnswerWithSnippets.schema()
# Out:
# {'properties': {'answer': {'title': 'Answer', 'type': 'string'},
#   'confidence': {'maximum': 1.0,
#    'minimum': 0.0,
#    'title': 'Confidence',
#    'type': 'number'},
#   'source_snippets': {'items': {'type': 'string'},
#    'title': 'Source Snippets',
#    'type': 'array'}},
#  'required': ['answer', 'confidence', 'source_snippets'],
#  'title': 'AnswerWithSnippets',
#  'type': 'object'}

# %%
my_prompt = RAG_PROMPT_TEMPLATE_JSON.format(
    context=RELEVANT_CONTEXT, user_query=USER_QUERY
)

data = {
    "inputs": my_prompt,
    "parameters": {
        "temperature": 2.0,
        "return_full_text": False,
        "grammar": {"type": "json", "value": AnswerWithSnippets.schema()},
        "max_new_tokens": 2000,
    },
}
import json

answer = json.loads(small_llm_client.post(json=data))[0]["generated_text"]
print(answer)

# %% [markdown]
# ✅ Although the answer is still nonsensical due to the high temperature, the generated output is now correct JSON, with the exact keys and types we defined in our grammar!
#
# It can then be parsed for further processing.

# %%
parsed_answer = literal_eval(answer)
print(parsed_answer)

# %% [markdown]
# ## Grammar on a local pipeline

# %%
from transformers import pipeline
from outlines.integrations.transformers import JSONPrefixAllowedTokens

pipe = pipeline("text-generation", model="unsloth/tinyllama")

prefix_allowed_tokens_fn = JSONPrefixAllowedTokens(
    schema=AnswerWithSnippets, tokenizer_or_pipe=pipe, whitespace_pattern=r" ?"
)
results = pipe(
    my_prompt,
    return_full_text=False,
    do_sample=False,
    max_new_tokens=1000,
    prefix_allowed_tokens_fn=prefix_allowed_tokens_fn,
)
print(results)

# %% [markdown]
# You can also use [Text-Generation-Inference](https://huggingface.co/docs/text-generation-inference/en/index) with constrained generation: the [documentation](https://huggingface.co/docs/text-generation-inference/en/conceptual/guidance) explains how to do this in detail, with further examples.

# %% [markdown]
# That's all for today, congrats for following along! 👏
